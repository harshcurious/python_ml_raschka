# %% [markdown]
# # Creating a simple RNN in pytoch

# %%
import torch
import torch.nn as nn
# Out:
# /home/hk/Documents/python_ml_raschka/.venv/lib/python3.13/site-packages/torch/_subclasses/functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
